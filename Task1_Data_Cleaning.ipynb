# %% [markdown]
# <a href="https://colab.research.google.com/github/kumarsusheel7497-collab/DataCleaning-Task1/blob/main/Task1_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-60716458-5bfd-45a4-b83c-6439fc8edf7c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-60716458-5bfd-45a4-b83c-6439fc8edf7c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("dirty_cafe_sales.csv")
df.head()
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee        2            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake        4            3.0        12.0            Cash
# 2    TXN_4271903  Cookie        4            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad        2            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %%
print("Shape of dataset:", df.shape)
print("\nFirst 5 rows:")
print(df.head())

print("\nColumn names:")
print(df.columns)

print("\nData types:")
print(df.dtypes)

print("\nMissing values:")
print(df.isnull().sum())

print("\nDuplicate rows:", df.duplicated().sum())
# Out:
# Shape of dataset: (10000, 8)
#
# First 5 rows:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee        2            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake        4            3.0        12.0            Cash
# 2    TXN_4271903  Cookie        4            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad        2            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11
#
# Column names:
# Index(['Transaction ID', 'Item', 'Quantity', 'Price Per Unit', 'Total Spent',
#        'Payment Method', 'Location', 'Transaction Date'],
#       dtype='object')
#
# Data types:
# Transaction ID      object
# Item                object
# Quantity            object
# ...

# %%
df = df.drop_duplicates()
print("Duplicate rows removed successfully.")
print("New shape:", df.shape)
# Out:
# Duplicate rows removed successfully.
# New shape: (10000, 8)

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
print("Updated column names:")
print(df.columns)
# Out:
# Updated column names:
# Index(['transaction_id', 'item', 'quantity', 'price_per_unit', 'total_spent',
#        'payment_method', 'location', 'transaction_date'],
#       dtype='object')

# %%
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].astype(str).str.strip().str.title()

print("Text values cleaned successfully.")
# Out:
# Text values cleaned successfully.

# %%
for col in df.select_dtypes(include=np.number).columns:
    df[col] = df[col].fillna(df[col].median())

# %%
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].replace("Nan", np.nan)
    df[col] = df[col].fillna("Unknown")

print("Missing values handled successfully.")
# Out:
# Missing values handled successfully.

# %%
for col in df.columns:
    if 'age' in col or 'salary' in col or 'price' in col or 'amount' in col:
        df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
for col in df.columns:
    if 'age' in col:
        df.loc[df[col] < 0, col] = np.nan
        df[col] = df[col].fillna(df[col].median())

    if 'salary' in col or 'price' in col or 'amount' in col:
        df.loc[df[col] < 0, col] = np.nan
        df[col] = df[col].fillna(df[col].median())

print("Invalid values handled successfully.")
# Out:
# Invalid values handled successfully.

# %%
print("Final shape:", df.shape)

print("\nFinal first 5 rows:")
print(df.head())

print("\nMissing values after cleaning:")
print(df.isnull().sum())

print("\nDuplicate rows after cleaning:", df.duplicated().sum())

print("\nFinal data types:")
print(df.dtypes)
# Out:
# Final shape: (10000, 8)
#
# Final first 5 rows:
#   transaction_id    item quantity  price_per_unit total_spent  payment_method  \
# 0    Txn_1961373  Coffee        2             2.0         4.0     Credit Card
# 1    Txn_4977031    Cake        4             3.0        12.0            Cash
# 2    Txn_4271903  Cookie        4             1.0       Error     Credit Card
# 3    Txn_7034554   Salad        2             5.0        10.0         Unknown
# 4    Txn_3160411  Coffee        2             2.0         4.0  Digital Wallet
#
#    location transaction_date
# 0  Takeaway       2023-09-08
# 1  In-Store       2023-05-16
# 2  In-Store       2023-07-19
# 3   Unknown       2023-04-27
# 4  In-Store       2023-06-11
#
# Missing values after cleaning:
# transaction_id      0
# item                0
# quantity            0
# price_per_unit      0
# total_spent         0
# payment_method      0
# location            0
# transaction_date    0
# dtype: int64
#
# Duplicate rows after cleaning: 0
# ...

# %%
df.to_csv("cleaned_data.csv", index=False)
print("Cleaned dataset saved successfully as cleaned_data.csv")
# Out:
# Cleaned dataset saved successfully as cleaned_data.csv

# %%
from google.colab import files
files.download("cleaned_data.csv")

# %%
df = pd.read_csv("cleaned_data.csv")
